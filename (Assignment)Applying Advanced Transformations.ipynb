# %% [markdown]
# # Applying Advanced Transformations

# %%
# imports
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os,json, time

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## The Task

# %% [markdown]
# I. Clean the files and combine them into one final DataFrame.

# %% [markdown]
# ### Observed Column Combinations for Superhero Info

# %%
superhero_info = pd.read_csv("Data/superhero_info - superhero_info.csv")
superhero_info.info()
superhero_info.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# ...

# %% [markdown]
# Columns to separate:
#    * Hero|Publisher
#    * Measurements
#        * Height (numeric)
#        * Weight (numeric)

# %%
superhero_info['Hero|Publisher'].str.split(pat="|",expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
superhero_info[['Hero','Publisher']] = superhero_info['Hero|Publisher'].str.split(pat="|",expand=True)
superhero_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# ...

# %%
superhero_info = superhero_info.drop(columns=['Hero|Publisher'])
superhero_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
hero_column_change = superhero_info.pop("Hero")
pub_column_change = superhero_info.pop("Publisher")

superhero_info.insert(0,"Hero",hero_column_change)
superhero_info.insert(1,"Publisher",pub_column_change)

superhero_info.head()
# Out:
#             Hero          Publisher Gender               Race Alignment  \
# 0         A-Bomb      Marvel Comics   Male              Human      good
# 1     Abe Sapien  Dark Horse Comics   Male      Icthyo Sapien      good
# 2       Abin Sur          DC Comics   Male            Ungaran      good
# 3    Abomination      Marvel Comics   Male  Human / Radiation       bad
# 4  Absorbing Man      Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
# Convert string column of dictionaries
superhero_info['Measurements'] = superhero_info['Measurements'].str.replace("'",'"')

superhero_info['Measurements'] = superhero_info['Measurements'].apply(json.loads)
superhero_info.head()
# Out:
#             Hero          Publisher Gender               Race Alignment  \
# 0         A-Bomb      Marvel Comics   Male              Human      good
# 1     Abe Sapien  Dark Horse Comics   Male      Icthyo Sapien      good
# 2       Abin Sur          DC Comics   Male            Ungaran      good
# 3    Abomination      Marvel Comics   Male  Human / Radiation       bad
# 4  Absorbing Man      Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
measurements = superhero_info['Measurements'].apply(pd.Series)
superhero_info = pd.concat((superhero_info, measurements),axis=1)

# Drop Measurements column
superhero_info = superhero_info.drop(columns=["Measurements"])

superhero_info.head()
# Out:
#             Hero          Publisher Gender               Race Alignment  \
# 0         A-Bomb      Marvel Comics   Male              Human      good
# 1     Abe Sapien  Dark Horse Comics   Male      Icthyo Sapien      good
# 2       Abin Sur          DC Comics   Male            Ungaran      good
# 3    Abomination      Marvel Comics   Male  Human / Radiation       bad
# 4  Absorbing Man      Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color    Height    Weight
# 0    No Hair    yellow    Unknown  203.0 cm  441.0 kg
# 1    No Hair      blue       blue  191.0 cm   65.0 kg
# 2    No Hair      blue        red  185.0 cm   90.0 kg
# 3    No Hair     green    Unknown  203.0 cm  441.0 kg
# 4    No Hair      blue    Unknown  193.0 cm  122.0 kg

# %%
# Make a list of all characters to replace
to_replace = [" cm", " kg"]
# run a loop to replace all of the characters in the list at once

for char in to_replace:
    superhero_info['Height'] = superhero_info['Height'].str.replace(char,
                                                                    '',
                                                                    regex=True)
    superhero_info['Weight'] = superhero_info['Weight'].str.replace(
        char, '', regex=False)

superhero_info.head()
# Out:
#             Hero          Publisher Gender               Race Alignment  \
# 0         A-Bomb      Marvel Comics   Male              Human      good
# 1     Abe Sapien  Dark Horse Comics   Male      Icthyo Sapien      good
# 2       Abin Sur          DC Comics   Male            Ungaran      good
# 3    Abomination      Marvel Comics   Male  Human / Radiation       bad
# 4  Absorbing Man      Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color Height Weight
# 0    No Hair    yellow    Unknown  203.0  441.0
# 1    No Hair      blue       blue  191.0   65.0
# 2    No Hair      blue        red  185.0   90.0
# 3    No Hair     green    Unknown  203.0  441.0
# 4    No Hair      blue    Unknown  193.0  122.0

# %% [markdown]
# ### Observed Column Combinations for Superhero Powers

# %%
superhero_powers = pd.read_csv("Data/superhero_powers - superhero_powers.csv")
superhero_powers.info()
superhero_powers.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
superhero_powers['Powers_split'] = superhero_powers['Powers'].str.split(pat=',',n=0)
superhero_powers.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
## exploding the column of lists
exploded = superhero_powers.explode('Powers_split')

## saving the unique values from the exploded column
cols_to_make = exploded['Powers_split'].dropna().unique()

for col in cols_to_make:
    superhero_powers[col] = superhero_powers['Powers'].str.contains(col)
superhero_powers.info()
superhero_powers.head()
# Out:
# C:\Users\nbeac\AppData\Local\Temp\ipykernel_14056\2540497929.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   superhero_powers[col] = superhero_powers['Powers'].str.contains(col)
# C:\Users\nbeac\AppData\Local\Temp\ipykernel_14056\2540497929.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   superhero_powers[col] = superhero_powers['Powers'].str.contains(col)
# ...

# %%
# superhero_info = superhero_info.drop(columns=["Measurements"])

superhero_powers = superhero_powers.drop(columns=["Powers","Powers_split"])

# %% [markdown]
# # Combining DataFrames

# %%
# superhero_info dataset
## get the Hero(id) information
heros = sorted(superhero_info['Hero'].unique())
heros[:4]
# Out:
# ['A-Bomb', 'Abe Sapien', 'Abin Sur', 'Abomination']

# %%
# make integers for each id
heros_id = range(len(heros))
heros_id
# Out:
# range(0, 455)

# %%
## Converting our range to a list and showing the first 10 values
# example_range = list(heros_id)
# example_range[:10]

# %%
# Zip together the unique_ids as the keys and the int_ids as the values
id_map = dict(zip(heros,heros_id))
id_map
# Out:
# {'A-Bomb': 0,
#  'Abe Sapien': 1,
#  'Abin Sur': 2,
#  'Abomination': 3,
#  'Absorbing Man': 4,
#  'Adam Strange': 5,
#  'Agent Bob': 6,
#  'Agent Zero': 7,
#  'Air-Walker': 8,
#  'Ajax': 9,
#  'Alan Scott': 10,
#  'Alien': 11,
#  'Amazo': 12,
#  'Ammo': 13,
#  'Angel': 14,
#  'Angel Dust': 15,
#  'Angel Salvadore': 16,
#  'Animal Man': 17,
#  'Annihilus': 18,
#  'Ant-Man': 19,
#  'Ant-Man II': 20,
#  'Anti-Venom': 21,
#  'Apocalypse': 22,
#  'Aqualad': 23,
#  'Aquaman': 24,
#  'Arachne': 25,
#  'Archangel': 26,
#  'Arclight': 27,
#  'Ardina': 28,
#  'Ares': 29,
#  'Ariel': 30,
#  'Armor': 31,
#  'Atlas': 32,
#  'Atom': 33,
#  'Atom Girl': 34,
#  'Atom II': 35,
#  'Aurora': 36,
#  'Azazel': 37,
#  'Bane': 38,
#  'Banshee': 39,
#  'Bantam': 40,
#  'Batgirl': 41,
#  'Batgirl IV': 42,
#  'Batgirl VI': 43,
#  'Batman': 44,
#  'Batman II': 45,
#  'Battlestar': 46,
#  'Beak': 47,
#  'Beast': 48,
#  'Beast Boy': 49,
#  'Beta Ray Bill': 50,
#  'Big Barda': 51,
#  'Big Man': 52,
# ...

# %%
## demonstrating using id_map to get iteger id 
example_str_id ="Wolverine"
id_map[example_str_id]
# Out:
# 444

# %%
superhero_info['Hero'].map(id_map)
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 458    450
# 459    451
# 460    452
# 461    453
# 462    454
# Name: Hero, Length: 463, dtype: int64

# %%
## overwriting the original id column 
superhero_info['ID'] = superhero_info['Hero'].replace(id_map)
superhero_info.head(3)
# Out:
#          Hero          Publisher Gender           Race Alignment Hair color  \
# 0      A-Bomb      Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien  Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
# 2    Abin Sur          DC Comics   Male        Ungaran      good    No Hair
#
#   Eye color Skin color Height Weight  ID
# 0    yellow    Unknown  203.0  441.0   0
# 1      blue       blue  191.0   65.0   1
# 2      blue        red  185.0   90.0   2

# %%
# Using pd.DataFrame and a dictionary
id_lookup = pd.DataFrame({'Hero Name': id_map.keys(),
                         'Hero ID':id_map.values()})
id_lookup.head(3)
# Out:
#     Hero Name  Hero ID
# 0      A-Bomb        0
# 1  Abe Sapien        1
# 2    Abin Sur        2

# %%
df = pd.merge(superhero_info, superhero_powers, left_on="Hero", right_on="hero_names")

df.head()
# Out:
#             Hero          Publisher Gender               Race Alignment  \
# 0         A-Bomb      Marvel Comics   Male              Human      good
# 1     Abe Sapien  Dark Horse Comics   Male      Icthyo Sapien      good
# 2       Abin Sur          DC Comics   Male            Ungaran      good
# 3    Abomination      Marvel Comics   Male  Human / Radiation       bad
# 4  Absorbing Man      Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color Height Weight  ID     hero_names  Agility  \
# 0    No Hair    yellow    Unknown  203.0  441.0   0         A-Bomb    False
# 1    No Hair      blue       blue  191.0   65.0   1     Abe Sapien     True
# 2    No Hair      blue        red  185.0   90.0   2       Abin Sur    False
# 3    No Hair     green    Unknown  203.0  441.0   3    Abomination    False
# 4    No Hair      blue    Unknown  193.0  122.0   4  Absorbing Man    False
#
#    Super Strength  Stamina  Super Speed  Accelerated Healing  Durability  \
# ...

# %%
df = df.drop(columns=['hero_names'])

# %%
id_column = df.pop("ID")

df.insert(1,"ID",id_column)
df.head()
# Out:
#             Hero  ID          Publisher Gender               Race Alignment  \
# 0         A-Bomb   0      Marvel Comics   Male              Human      good
# 1     Abe Sapien   1  Dark Horse Comics   Male      Icthyo Sapien      good
# 2       Abin Sur   2          DC Comics   Male            Ungaran      good
# 3    Abomination   3      Marvel Comics   Male  Human / Radiation       bad
# 4  Absorbing Man   4      Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color Height Weight  Agility  Super Strength  \
# 0    No Hair    yellow    Unknown  203.0  441.0    False            True
# 1    No Hair      blue       blue  191.0   65.0     True            True
# 2    No Hair      blue        red  185.0   90.0    False           False
# 3    No Hair     green    Unknown  203.0  441.0    False            True
# 4    No Hair      blue    Unknown  193.0  122.0    False            True
#
# ...

# %% [markdown]
# ### Compare the average weight of Heros who have Super Speed to those who do not.
